# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv("resources/young_survey.csv")
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Spending on looks  \
# 0      1.0  5.0   5.0                1.0  ...                3.0
# 1      2.0  3.0   5.0                4.0  ...                2.0
# 2      5.0  3.0   5.0                3.0  ...                3.0
# 3      1.0  2.0   2.0                1.0  ...                4.0
# 4      3.0  5.0   3.0                1.0  ...                3.0
#
#    Spending on gadgets  Spending on healthy eating   Age  Height  Weight  \
# ...

# %%
basic_info = df.iloc[:, 140:]
basic_info
# Out:
#       Age  Height  Weight  Number of siblings  Gender Handedness  \
# 0    20.0   163.0    48.0                 1.0  female      right
# 1    19.0   163.0    58.0                 2.0  female      right
# 2    20.0   176.0    67.0                 2.0  female      right
# 3    22.0   172.0    59.0                 1.0  female      right
# 4    20.0   170.0    59.0                 1.0  female      right
# ..    ...     ...     ...                 ...     ...        ...
# 992  20.0   164.0    57.0                 1.0  female      right
# 993  27.0   183.0    80.0                 5.0    male       left
# 994  18.0   173.0    75.0                 0.0  female      right
# 995  25.0   173.0    58.0                 1.0  female      right
# 996  21.0   185.0    72.0                 1.0    male      right
#
#              Education
# 0    bachelor's degree
# 1    bachelor's degree
# 2          high school
# 3    bachelor's degree
# 4          high school
# ..                 ...
# ...

# %%
basic_info.describe()
# Out:
#               Age      Height      Weight  Number of siblings
# count  997.000000  982.000000  981.000000          995.000000
# mean    20.439318  173.610998   66.407747            1.300503
# std      2.835443    9.373842   13.862403            1.015548
# min     15.000000  148.000000   41.000000            0.000000
# 25%     19.000000  167.000000   55.000000            1.000000
# 50%     20.000000  173.000000   64.000000            1.000000
# 75%     22.000000  180.000000   75.000000            2.000000
# max     30.000000  203.000000  165.000000           10.000000

# %%
 basic_info['Gender'].value_counts()
# Out:
# female    587
# male      405
# Name: Gender, dtype: int64

# %%
 basic_info['Handedness'].value_counts()
# Out:
# right    895
# left      99
# Name: Handedness, dtype: int64

# %%
 basic_info['Education'].value_counts()
# Out:
# high school          618
# bachelor's degree    207
# master's degree       78
# middle school         78
# elementary school     10
# doctorate degree       5
# Name: Education, dtype: int64

# %%
sns.violinplot(data=basic_info, y='Age')
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.violinplot(data=basic_info, x='Gender', y='Age')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.violinplot(data=basic_info, x='Gender', y='Age', hue='Handedness')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
    sns.jointplot(data=basic_info, x='Height', y='Weight')

# %%
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Spending on looks  \
# 0      1.0  5.0   5.0                1.0  ...                3.0
# 1      2.0  3.0   5.0                4.0  ...                2.0
# 2      5.0  3.0   5.0                3.0  ...                3.0
# 3      1.0  2.0   2.0                1.0  ...                4.0
# 4      3.0  5.0   3.0                1.0  ...                3.0
#
#    Spending on gadgets  Spending on healthy eating   Age  Height  Weight  \
# ...

# %%
for i in range(len(df.columns)):
    print(i, df.columns[i])
# Out:
# 0 Music
# 1 Slow songs or fast songs
# 2 Dance
# 3 Folk
# 4 Country
# 5 Classical music
# 6 Musical
# 7 Pop
# 8 Rock
# 9 Metal or Hardrock
# 10 Punk
# 11 Hiphop, Rap
# 12 Reggae, Ska
# 13 Swing, Jazz
# 14 Rock n roll
# 15 Alternative
# 16 Latino
# 17 Techno, Trance
# 18 Opera
# 19 Movies
# 20 Horror
# 21 Thriller
# 22 Comedy
# 23 Romantic
# 24 Sci-fi
# 25 War
# 26 Fantasy/Fairy tales
# 27 Animated
# 28 Documentary
# 29 Western
# 30 Action
# 31 History
# 32 Psychology
# 33 Politics
# 34 Mathematics
# 35 Physics
# 36 Internet
# 37 PC
# 38 Economy Management
# 39 Biology
# 40 Chemistry
# 41 Reading
# 42 Geography
# 43 Foreign languages
# 44 Medicine
# 45 Law
# 46 Cars
# 47 Art exhibitions
# 48 Religion
# 49 Countryside, outdoors
# 50 Dancing
# 51 Musical instruments
# 52 Writing
# 53 Passive sport
# 54 Active sport
# 55 Gardening
# 56 Celebrities
# 57 Shopping
# 58 Science and technology
# 59 Theatre
# 60 Fun with friends
# 61 Adrenaline sports
# 62 Pets
# 63 Flying
# 64 Storm
# ...

# %%
music = df.iloc[:, :19]

# %%
music
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0      5.0                       3.0    2.0   1.0      2.0              2.0
# 1      4.0                       4.0    2.0   1.0      1.0              1.0
# 2      5.0                       5.0    2.0   2.0      3.0              4.0
# 3      5.0                       3.0    2.0   1.0      1.0              1.0
# 4      5.0                       3.0    4.0   3.0      2.0              4.0
# ..     ...                       ...    ...   ...      ...              ...
# 992    5.0                       2.0    5.0   2.0      2.0              5.0
# 993    4.0                       4.0    5.0   1.0      3.0              4.0
# 994    4.0                       3.0    1.0   1.0      2.0              2.0
# 995    5.0                       3.0    3.0   3.0      1.0              3.0
# 996    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %%
sns.heatmap(music.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()['Age'].sort_values(ascending=False)
# Out:
# Age                        1.000000
# Weight                     0.238893
# Elections                  0.212319
# Prioritising workload      0.156256
# Reliability                0.148141
#                              ...
# Mood swings               -0.111890
# Getting up                -0.119888
# Questionnaires or polls   -0.128187
# Shopping centres          -0.133800
# Changing the past         -0.146895
# Name: Age, Length: 139, dtype: float64

# %%
interests = df.loc[:, 'History': 'Pets']
interests.head()
# Out:
#    History  Psychology  Politics  Mathematics  Physics  Internet   PC  \
# 0      1.0         5.0       1.0          3.0      3.0       5.0  3.0
# 1      1.0         3.0       4.0          5.0      2.0       4.0  4.0
# 2      1.0         2.0       1.0          5.0      2.0       4.0  2.0
# 3      4.0         4.0       5.0          4.0      1.0       3.0  1.0
# 4      3.0         2.0       3.0          2.0      2.0       2.0  2.0
#
#    Economy Management  Biology  Chemistry  ...  Passive sport  Active sport  \
# 0                 5.0      3.0        3.0  ...            1.0           5.0
# 1                 5.0      1.0        1.0  ...            1.0           1.0
# 2                 4.0      1.0        1.0  ...            5.0           2.0
# 3                 2.0      3.0        3.0  ...            1.0           1.0
# 4                 2.0      3.0        3.0  ...            3.0           1.0
#
#    Gardening  Celebrities  Shopping  Science and technology  Theatre  \
# ...

# %%
corr = interests.corr()
corr
# Out:
#                          History  Psychology  Politics  Mathematics   Physics  \
# History                 1.000000    0.281493  0.400845     0.008328  0.079638
# Psychology              0.281493    1.000000  0.195338     0.043030  0.065774
# Politics                0.400845    0.195338  1.000000     0.104033  0.130293
# Mathematics             0.008328    0.043030  0.104033     1.000000  0.595188
# Physics                 0.079638    0.065774  0.130293     0.595188  1.000000
# Internet                0.022010    0.000075  0.058863     0.157779  0.103793
# PC                      0.027346   -0.077712  0.088846     0.295564  0.339429
# Economy Management      0.054872    0.087072  0.304575     0.218796  0.010678
# Biology                 0.014807    0.202913 -0.090532     0.078043  0.212261
# Chemistry               0.014117    0.058541 -0.058849     0.181953  0.322827
# Reading                 0.262948    0.231861  0.089448    -0.033184 -0.062080
# ...

# %%
corr['History'].sort_values(ascending=False)
# Out:
# History                   1.000000
# Politics                  0.400845
# Geography                 0.327354
# Law                       0.298363
# Psychology                0.281493
# Reading                   0.262948
# Religion                  0.203840
# Art exhibitions           0.200643
# Theatre                   0.185301
# Writing                   0.164617
# Foreign languages         0.145471
# Science and technology    0.135597
# Musical instruments       0.107279
# Countryside, outdoors     0.096609
# Physics                   0.079638
# Active sport              0.064929
# Adrenaline sports         0.061201
# Economy Management        0.054872
# Cars                      0.050644
# Medicine                  0.040023
# Gardening                 0.033196
# Dancing                   0.032925
# Pets                      0.031920
# PC                        0.027346
# Fun with friends          0.024960
# Internet                  0.022010
# Biology                   0.014807
# ...

# %%
sns.clustermap(corr)

# %% [markdown]
# ## HW

# %%
df= pd.read_csv("resources/occupations.csv")
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
df[df['gender']=='F']['occupation'].value_counts()
# Out:
# student          60
# administrator    36
# other            36
# librarian        29
# educator         26
# writer           19
# artist           13
# healthcare       11
# marketing        10
# programmer        6
# homemaker         6
# none              4
# executive         3
# salesman          3
# scientist         3
# entertainment     2
# lawyer            2
# engineer          2
# technician        1
# retired           1
# Name: occupation, dtype: int64

# %%
df[df['gender']=='M']['occupation'].value_counts()
# Out:
# student          136
# other             69
# educator          69
# engineer          65
# programmer        60
# administrator     43
# executive         29
# scientist         28
# writer            26
# technician        26
# librarian         22
# marketing         16
# entertainment     16
# artist            15
# retired           13
# lawyer            10
# salesman           9
# doctor             7
# none               5
# healthcare         5
# homemaker          1
# Name: occupation, dtype: int64

# %%
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df= pd.read_csv("resources/young_survey.csv")
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Spending on looks  \
# 0      1.0  5.0   5.0                1.0  ...                3.0
# 1      2.0  3.0   5.0                4.0  ...                2.0
# 2      5.0  3.0   5.0                3.0  ...                3.0
# 3      1.0  2.0   2.0                1.0  ...                4.0
# 4      3.0  5.0   3.0                1.0  ...                3.0
#
#    Spending on gadgets  Spending on healthy eating   Age  Height  Weight  \
# ...

# %%
music = df.iloc[:, :19]

# %%
get_up = df['Getting up']

# %%
music['Getting up'] = df['Getting up']

# %%
sns.heatmap(music.corr())
# Out:
# <AxesSubplot:>

# %%
music.corr()['Getting up'].sort_values(ascending=False)
# Out:
# Getting up                  1.000000
# Rock                        0.105245
# Music                       0.090009
# Pop                         0.079101
# Hiphop, Rap                 0.038980
# Rock n roll                 0.028889
# Alternative                 0.027540
# Dance                       0.027249
# Techno, Trance              0.019863
# Swing, Jazz                 0.019556
# Classical music             0.014285
# Musical                     0.011869
# Reggae, Ska                -0.008434
# Latino                     -0.015060
# Country                    -0.025315
# Metal or Hardrock          -0.026769
# Punk                       -0.029189
# Folk                       -0.049612
# Slow songs or fast songs   -0.052613
# Opera                      -0.071819
# Name: Getting up, dtype: float64

# %%
df.corr()['Getting up'][1:19].sort_values(ascending=False)
# Out:
# Rock                        0.105245
# Pop                         0.079101
# Hiphop, Rap                 0.038980
# Rock n roll                 0.028889
# Alternative                 0.027540
# Dance                       0.027249
# Techno, Trance              0.019863
# Swing, Jazz                 0.019556
# Classical music             0.014285
# Musical                     0.011869
# Reggae, Ska                -0.008434
# Latino                     -0.015060
# Country                    -0.025315
# Metal or Hardrock          -0.026769
# Punk                       -0.029189
# Folk                       -0.049612
# Slow songs or fast songs   -0.052613
# Opera                      -0.071819
# Name: Getting up, dtype: float64

# %%
df= pd.read_csv("resources/young_survey.csv")
df.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...  Spending on looks  \
# 0      1.0  5.0   5.0                1.0  ...                3.0
# 1      2.0  3.0   5.0                4.0  ...                2.0
# 2      5.0  3.0   5.0                3.0  ...                3.0
# 3      1.0  2.0   2.0                1.0  ...                4.0
# 4      3.0  5.0   3.0                1.0  ...                3.0
#
#    Spending on gadgets  Spending on healthy eating   Age  Height  Weight  \
# ...

# %%
df[['Musical instruments', 'Writing']].corr()
# Out:
#                      Musical instruments   Writing
# Musical instruments             1.000000  0.343816
# Writing                         0.343816  1.000000

# %%
df[['Spending on looks', 'Branded clothing']].corr()
# Out:
#                    Spending on looks  Branded clothing
# Spending on looks           1.000000          0.418399
# Branded clothing            0.418399          1.000000

# %%
df[['Writing notes', 'New environment']].corr()
# Out:
#                  Writing notes  New environment
# Writing notes         1.000000        -0.079397
# New environment      -0.079397         1.000000

# %%
df[['Prioritising workload', 'Healthy eating']].corr()
# Out:
#                        Prioritising workload  Healthy eating
# Prioritising workload               1.000000        0.242131
# Healthy eating                      0.242131        1.000000

# %%
df= pd.read_csv("resources/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.violinplot(data=df, y='Age')
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.violinplot(data=df, y='Age')

# %%
sns.kdeplot(df['Age'], bw=1)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(data=df, y='Fare', x='Age')

# %%
# 나이별 요금 분포
df.plot(kind='scatter', x='Age', y='Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
for i in range(3):
    print(i+1, "등석 사망자와 생존자")
    print(df[df['Pclass']==i+1]['Survived'].value_counts())
    print(생존율)
    print()
# Out:
# 1 등석 사망자와 생존자
# 1    136
# 0     80
# Name: Survived, dtype: int64
# 2 등석 사망자와 생존자
# 0    97
# 1    87
# Name: Survived, dtype: int64
# 3 등석 사망자와 생존자
# 0    372
# 1    119
# Name: Survived, dtype: int64

# %%
sns.lmplot(data=df, x='Age', y='Survived')

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.catplot(data=df, x='Survived', y='Age', kind='violin')

# %%
sns.stripplot(data=df, x='Survived', y='Age', kind='violin')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-23970f3cb9f6> in <module>
# ----> 1 sns.stripplot(data=df, x='Survived', y='Age', kind='violin')
#
# ~/anaconda/envs/py38/lib/python3.8/site-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2790                        linewidth=linewidth))
#    2791
# -> 2792     plotter.plot(ax, kwargs)
#    2793     return ax
#    2794
#
# ~/anaconda/envs/py38/lib/python3.8/site-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1200     def plot(self, ax, kws):
#    1201         """Make the plot."""
# -> 1202         self.draw_stripplot(ax, kws)
#    1203         self.add_legend_data(ax)
#    1204         self.annotate_axes(ax)
#
# ...

# %%
gender_survived = df[['Sex', 'Survived']]
gender_survived
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
gender_survived[gender_survived['Sex']=='male'].value_counts()
# 생존율 18%
# Out:
# Sex   Survived
# male  0           468
#       1           109
# dtype: int64

# %%
gender_survived[gender_survived['Sex']=='female'].value_counts()
# 생존율 74%
# Out:
# Sex     Survived
# female  1           233
#         0            81
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
